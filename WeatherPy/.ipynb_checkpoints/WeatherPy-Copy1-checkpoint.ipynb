# %%
#pip install citipy

# %%
# Dependencies and Setup
import csv
import os
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
import datetime
from scipy import stats
from scipy.stats import linregress

# Import API key
from api_keys import weather_api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %%
import datetime
 
date_only = datetime.datetime.now().date()
 
print(date_only)
# Out:
# 2020-09-09

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 614

# %%
# Weather API Config
url = "http://api.openweathermap.org/data/2.5/weather?"
units = "metric"

# %%
city = 'rocha'
query_url = f"{url}appid={weather_api_key}&q={city}&units={units}"
weather_response = requests.get(query_url)
weather_json = weather_response.json()
temperature = weather_json["main"]["temp"]
temperature
# Out:
# 16.84

# %%
city_data = []

baseurl = f"{url}appid={weather_api_key}"
for i, city in enumerate(cities):
    cityurl = baseurl + '&q=' + city
    print('Processing Record ' + str(i) + ' of ' + city)
    try:
        weather_response = requests.get(cityurl)
        weather_json = weather_response.json()
        max_temp = weather_json["main"]["temp_max"]
        lat = weather_json["coord"]["lat"]
        lng = weather_json["coord"]["lon"]
        hum = weather_json["main"]["humidity"]
        cloud = weather_json["clouds"]["all"]
        windspeed = weather_json["wind"]["speed"]
        country = weather_json["sys"]["country"]
        date = weather_json["dt"]
        city_data.append({'City':city,
                         'Lat':lat,
                         'Lng':lng,
                         'Max_Temp':max_temp,
                         'Humidity':hum,
                         'Cloudiness':cloud,
                         'Wind Speed':windspeed,
                         'Country':country,
                          'Date':date
                         })
    except:
        print('City not found, skipping...')
# Out:
# Processing Record 0 of busselton
# Processing Record 1 of zhuozhou
# City not found, skipping...
# Processing Record 2 of cidreira
# Processing Record 3 of chokurdakh
# Processing Record 4 of grand river south east
# City not found, skipping...
# Processing Record 5 of thompson
# Processing Record 6 of manta
# Processing Record 7 of dickson
# Processing Record 8 of ushuaia
# Processing Record 9 of esperance
# Processing Record 10 of barentsburg
# City not found, skipping...
# Processing Record 11 of mataura
# Processing Record 12 of pisco
# Processing Record 13 of punta arenas
# Processing Record 14 of gazojak
# Processing Record 15 of adelanto
# Processing Record 16 of khatanga
# Processing Record 17 of barrow
# Processing Record 18 of ketchikan
# Processing Record 19 of jamestown
# Processing Record 20 of boysun
# Processing Record 21 of masuguru
# Processing Record 22 of alice springs
# Processing Record 23 of talaya
# Processing Record 24 of komsomolskiy
# Processing Record 25 of hithadhoo
# Processing Record 26 of kapaa
# Processing Record 27 of warmbad
# Processing Record 28 of albany
# Processing Record 29 of lebu
# Processing Record 30 of yichang
# Processing Record 31 of caravelas
# Processing Record 32 of kamyshin
# Processing Record 33 of karoi
# Processing Record 34 of bredasdorp
# Processing Record 35 of hermanus
# Processing Record 36 of hobart
# Processing Record 37 of longyearbyen
# Processing Record 38 of rikitea
# Processing Record 39 of hilo
# Processing Record 40 of roros
# Processing Record 41 of chapais
# Processing Record 42 of meru
# Processing Record 43 of kodiak
# Processing Record 44 of saskylakh
# Processing Record 45 of sinnamary
# Processing Record 46 of avarua
# Processing Record 47 of new norfolk
# Processing Record 48 of tiksi
# Processing Record 49 of hovd
# Processing Record 50 of pauini
# Processing Record 51 of vaini
# Processing Record 52 of ribeira grande
# Processing Record 53 of tasiilaq
# Processing Record 54 of xining
# Processing Record 55 of mys shmidta
# City not found, skipping...
# Processing Record 56 of opoczno
# Processing Record 57 of vila velha
# Processing Record 58 of taolanaro
# City not found, skipping...
# Processing Record 59 of jieshi
# Processing Record 60 of kungurtug
# Processing Record 552 of kazalinsk
# City not found, skipping...
# Processing Record 553 of sao domingos
# Processing Record 554 of hereford
# Processing Record 555 of kollumerland
# City not found, skipping...
# Processing Record 556 of barra patuca
# Processing Record 557 of narrabri
# Processing Record 558 of zhigansk
# Processing Record 559 of balakovo
# Processing Record 560 of asayita
# City not found, skipping...
# Processing Record 561 of xuddur
# Processing Record 562 of karpogory
# Processing Record 563 of florianopolis
# Processing Record 564 of qadian
# Processing Record 565 of rechitsy
# Processing Record 566 of almaznyy
# Processing Record 567 of isla mujeres
# Processing Record 568 of linqiong
# Processing Record 569 of mnogovershinnyy
# Processing Record 570 of zaysan
# Processing Record 571 of meulaboh
# Processing Record 572 of capoterra
# Processing Record 573 of tinskoy
# Processing Record 574 of dolores
# Processing Record 575 of arkadak
# Processing Record 576 of tayoltita
# Processing Record 577 of roald
# Processing Record 578 of cap malheureux
# Processing Record 579 of dickinson
# Processing Record 580 of narsaq
# Processing Record 581 of lazaro cardenas
# Processing Record 582 of harper
# Processing Record 583 of somanda
# Processing Record 584 of kindu
# Processing Record 585 of rio grande
# Processing Record 586 of achisay
# City not found, skipping...
# Processing Record 587 of mangrol
# Processing Record 588 of yomitan
# City not found, skipping...
# Processing Record 589 of mehamn
# Processing Record 590 of byron bay
# Processing Record 591 of urengoy
# Processing Record 592 of azad shahr
# Processing Record 593 of singkang
# Processing Record 594 of liepaja
# Processing Record 595 of sawtell
# Processing Record 596 of aksu
# Processing Record 597 of kawalu
# Processing Record 598 of vila
# Processing Record 599 of camacha
# Processing Record 600 of maniitsoq
# Processing Record 601 of liwale
# Processing Record 602 of birjand
# Processing Record 603 of nicolas bravo
# Processing Record 604 of collie
# Processing Record 605 of ponca city
# Processing Record 606 of okhotsk
# Processing Record 607 of puerto leguizamo
# Processing Record 608 of ivybridge
# Processing Record 609 of tungor
# Processing Record 610 of kamenskoye
# City not found, skipping...
# Processing Record 611 of fandriana
# Processing Record 612 of gizo
# Processing Record 613 of jiayuguan

# %%
# Convert to Dataframe
city_weather_df
# Out:
#            City    Lat     Lng  Max_Temp  Humidity  Cloudiness  Wind Speed  \
# 0     busselton -33.65  115.33    285.93        77          65        6.78
# 1      cidreira -30.18  -50.21    290.80        96          92        9.07
# 2    chokurdakh  70.63  147.92    277.95        80          99        2.51
# 3      thompson  55.74  -97.86    284.69        69         100        3.81
# 4         manta  -0.95  -80.73    297.07        73          37        4.71
# ..          ...    ...     ...       ...       ...         ...         ...
# 557   ivybridge  50.39   -3.92    286.48        84           1        4.10
# 558      tungor  53.38  142.96    283.67        92          54        5.30
# 559   fandriana -20.23   47.38    285.49        89          65        1.20
# 560        gizo  -8.10  156.84    299.44        83         100        4.47
# 561   jiayuguan  39.82   98.30    289.61        44          21        2.66
#
#     Country        Date
# 0        AU  1599684413
# 1        BR  1599684414
# 2        RU  1599684414
# 3        CA  1599684415
# 4        EC  1599684415
# ..      ...         ...
# 557      GB  1599684608
# 558      RU  1599684608
# 559      MG  1599684609
# 560      SB  1599684609
# 561      CN  1599684609
#
# [562 rows x 9 columns]

# %%
# Convert Kelvin to Fahernheit
city_weather_df["Max_Temp"] =  (city_weather_df["Max_Temp"] - 273.15) * 1.8 + 32
city_weather_df
# Out:
#            City    Lat     Lng  Max_Temp  Humidity  Cloudiness  Wind Speed  \
# 0     busselton -33.65  115.33    55.004        77          65        6.78
# 1      cidreira -30.18  -50.21    63.770        96          92        9.07
# 2    chokurdakh  70.63  147.92    40.640        80          99        2.51
# 3      thompson  55.74  -97.86    52.772        69         100        3.81
# 4         manta  -0.95  -80.73    75.056        73          37        4.71
# ..          ...    ...     ...       ...       ...         ...         ...
# 557   ivybridge  50.39   -3.92    55.994        84           1        4.10
# 558      tungor  53.38  142.96    50.936        92          54        5.30
# 559   fandriana -20.23   47.38    54.212        89          65        1.20
# 560        gizo  -8.10  156.84    79.322        83         100        4.47
# 561   jiayuguan  39.82   98.30    61.628        44          21        2.66
#
#     Country        Date
# 0        AU  1599684413
# 1        BR  1599684414
# 2        RU  1599684414
# 3        CA  1599684415
# 4        EC  1599684415
# ..      ...         ...
# 557      GB  1599684608
# 558      RU  1599684608
# 559      MG  1599684609
# 560      SB  1599684609
# 561      CN  1599684609
#
# [562 rows x 9 columns]

# %%
# Convert Windspeed from m/s to mph
city_weather_df["Wind Speed"] =  city_weather_df["Wind Speed"] * 2.236936
city_weather_df
# Out:
#            City    Lat     Lng  Max_Temp  Humidity  Cloudiness  Wind Speed  \
# 0     busselton -33.65  115.33    55.004        77          65   15.166426
# 1      cidreira -30.18  -50.21    63.770        96          92   20.289010
# 2    chokurdakh  70.63  147.92    40.640        80          99    5.614709
# 3      thompson  55.74  -97.86    52.772        69         100    8.522726
# 4         manta  -0.95  -80.73    75.056        73          37   10.535969
# ..          ...    ...     ...       ...       ...         ...         ...
# 557   ivybridge  50.39   -3.92    55.994        84           1    9.171438
# 558      tungor  53.38  142.96    50.936        92          54   11.855761
# 559   fandriana -20.23   47.38    54.212        89          65    2.684323
# 560        gizo  -8.10  156.84    79.322        83         100    9.999104
# 561   jiayuguan  39.82   98.30    61.628        44          21    5.950250
#
#     Country        Date
# 0        AU  1599684413
# 1        BR  1599684414
# 2        RU  1599684414
# 3        CA  1599684415
# 4        EC  1599684415
# ..      ...         ...
# 557      GB  1599684608
# 558      RU  1599684608
# 559      MG  1599684609
# 560      SB  1599684609
# 561      CN  1599684609
#
# [562 rows x 9 columns]

# %%
# Save to CSV - Problem, this stopped working
output_file = city_weather_df.to_csv('citydata.csv', index=False)

# %%
# Inspect the data and remove the cities where the humidity > 100% (no rows found > 100%)
Humidityover100_df = city_weather_df[(city_weather_df.Humidity > 100)]
Humidityover100_df
# Out:
# Empty DataFrame
# Columns: [City, Lat, Lng, Max_Temp, Humidity, Cloudiness, Wind Speed, Country, Date]
# Index: []

# %%
chart_title = "City Latitude vs Max Temperature (" + str(datetime.datetime.now().date()) + ")"
city_weather_df.plot(kind="scatter", x="Lat", y="Max_Temp",s = 99, grid=True, 
              figsize=(13,8), title = chart_title)
plt.ylabel("Max Temperature (F)")
plt.xlabel("Latitude")
plt.show()

# %%
## The Scatter plots visualizes temperature in cities by Latitude.  As seen the cities in the far North and South
# are much lower than ciries near the equator (Latitude = 0)
# The code pulls in a varierty of measurements by city from openweather api.  After converting to Fahrenheit from
# Kelvin we plot the data in a scatter.
# Problem: Why is the chart cut off?

# %%
chart_title = "City Latitude vs Humidity (" + str(datetime.datetime.now().date()) + ")"
city_weather_df.plot(kind="scatter", x="Lat", y="Humidity",s = 99, grid=True, 
              figsize=(13,8), title = chart_title)
plt.ylabel("Humidity (%)")
plt.xlabel("Latitude")
plt.show()

# %%
## This scatter plots Humidity versus Latitude.
# Except for near the equator (where all data points show at least 40% but are clustered at 60% and above,
# humidity has a wide range across Latitudes

# %%
chart_title = "City Latitude vs Cloudiness (" + str(datetime.datetime.now().date()) + ")"
city_weather_df.plot(kind="scatter", x="Lat", y="Cloudiness",s = 99, grid=True, 
              figsize=(13,8), title = chart_title)
plt.ylabel("Cloudiness (%)")
plt.xlabel("Latitude")
plt.show()

# %%
## This scatter plots Cloudiness versus Latitude.  Here we see many data points at 0 which means areas like So Cal
# or the Sahara desert that get no clouds (or rain).  There are also many points at 100% which is where the gloomy
# areas are like London (fog  = 100% Cloudiness AND 100% Humidity)

# %%
chart_title = "City Latitude vs Wind Speed (" + str(datetime.datetime.now().date()) + ")"
city_weather_df.plot(kind="scatter", x="Lat", y="Wind Speed",s = 99, grid=True, 
              figsize=(13,8), title = chart_title)
plt.ylabel("Wind Speed (mph)")
plt.xlabel("Latitude")
plt.show()

# %%
## This scatter plots Wind Speed versus Latitude.  The units is provided in meters/sec which has been
# converted to mile per hour.  There are a few cities that have such a high wind speed but that is likely
# due to a "windy day" at the time of data collection.  Therefore This scatter really doesn;t tell us much.
# We would have to have a data over a longer period like a season to understand wind speed patterns.

# %%
# Create Southern hemi dataframe
so_city_weather_df = city_weather_df[(city_weather_df.Lat < 0)]
so_city_weather_df
# Out:
#                  City    Lat     Lng  Max_Temp  Humidity  Cloudiness  \
# 0           busselton -33.65  115.33    55.004        77          65
# 1            cidreira -30.18  -50.21    63.770        96          92
# 4               manta  -0.95  -80.73    75.056        73          37
# 6             ushuaia -54.80  -68.30    40.064        72          33
# 7           esperance -33.87  121.90    64.256        66          87
# ..                ...    ...     ...       ...       ...         ...
# 550            liwale  -9.77   37.93    66.650        74          10
# 553            collie -33.37  116.15    55.004        77          96
# 556  puerto leguizamo  -0.19  -74.78    89.924        49          79
# 559         fandriana -20.23   47.38    54.212        89          65
# 560              gizo  -8.10  156.84    79.322        83         100
#
#      Wind Speed Country        Date
# 0     15.166426      AU  1599684413
# 1     20.289010      BR  1599684414
# 4     10.535969      EC  1599684415
# 6      2.773801      AR  1599684310
# 7     13.645310      AU  1599684417
# ..          ...     ...         ...
# 550    1.163207      TZ  1599684606
# 553    8.321402      AU  1599684607
# 556    3.937007      CO  1599684608
# 559    2.684323      MG  1599684609
# 560    9.999104      SB  1599684609
#
# [196 rows x 9 columns]

# %%
# Create Northern hemi dataframe
no_city_weather_df = city_weather_df[(city_weather_df.Lat > 0)]
no_city_weather_df
# Out:
#            City    Lat     Lng  Max_Temp  Humidity  Cloudiness  Wind Speed  \
# 2    chokurdakh  70.63  147.92    40.640        80          99    5.614709
# 3      thompson  55.74  -97.86    52.772        69         100    8.522726
# 5       dickson  36.08  -87.39    87.998        57           0    2.684323
# 11      gazojak  41.19   61.40    66.560        26           0    9.708302
# 12     adelanto  34.58 -117.41    80.006        12           0    2.997494
# ..          ...    ...     ...       ...       ...         ...         ...
# 554  ponca city  36.71  -97.09    53.006        97         100   14.428237
# 555     okhotsk  59.38  143.30    48.146        56           0    4.227809
# 557   ivybridge  50.39   -3.92    55.994        84           1    9.171438
# 558      tungor  53.38  142.96    50.936        92          54   11.855761
# 561   jiayuguan  39.82   98.30    61.628        44          21    5.950250
#
#     Country        Date
# 2        RU  1599684414
# 3        CA  1599684415
# 5        US  1599684415
# 11       TM  1599684418
# 12       US  1599684419
# ..      ...         ...
# 554      US  1599684322
# 555      RU  1599684607
# 557      GB  1599684608
# 558      RU  1599684608
# 561      CN  1599684609
#
# [366 rows x 9 columns]

# %%
# Add the linear regression equation and line to plot for Southern hemi
x_values = so_city_weather_df['Lat']
y_values = so_city_weather_df['Max_Temp']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
so_city_weather_df.plot(kind="scatter", x="Lat", y="Max_Temp",s = 98, grid=False, 
              figsize=(13,8), title = "Southern Hemi - Max Temp vs Latitude")
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(-55,100),fontsize=18,color="red")
plt.xlabel('Latitude')
plt.ylabel('Max_Temp')
print(f"The r-squared is: {rvalue**2}")
plt.show()
# Out:
# The r-squared is: 0.5920164465334218

# %%
# Add the linear regression equation and line to plot for Northern hemi
x_values = no_city_weather_df['Lat']
y_values = no_city_weather_df['Max_Temp']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
no_city_weather_df.plot(kind="scatter", x="Lat", y="Max_Temp",s = 98, grid=False, 
              figsize=(13,8), title = "Northern Hemi - Max Temp vs Latitude")
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(5,30),fontsize=18,color="red")
plt.xlabel('Latitude')
plt.ylabel('Max_Temp')
print(f"The r-squared is: {rvalue**2}")
plt.show()
# Out:
# The r-squared is: 0.637618862742333

# %%
# Add the linear regression equation and line to plot for Southern hemi
x_values = so_city_weather_df['Lat']
y_values = so_city_weather_df['Humidity']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
so_city_weather_df.plot(kind="scatter", x="Lat", y="Humidity",s = 98, grid=False, 
              figsize=(13,8), title = "Southern Hemi - Humidity vs Latitude")
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(-55,15),fontsize=18,color="red")
plt.xlabel('Latitude')
plt.ylabel('Humidity')
print(f"The r-squared is: {rvalue**2}")
plt.show()
# Out:
# The r-squared is: 0.02244328544812654

# %%
# Add the linear regression equation and line to plot for Northern hemi
x_values = no_city_weather_df['Lat']
y_values = no_city_weather_df['Humidity']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
no_city_weather_df.plot(kind="scatter", x="Lat", y="Humidity",s = 98, grid=False, 
              figsize=(13,8), title = "Northern Hemi - Humidity vs Latitude")
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(0,11),fontsize=18,color="red")
plt.xlabel('Latitude')
plt.ylabel('Humidity')
print(f"The r-squared is: {rvalue**2}")
plt.show()
# Out:
# The r-squared is: 0.0015644899585150617

# %%
# Add the linear regression equation and line to plot for Southern hemi
x_values = so_city_weather_df['Lat']
y_values = so_city_weather_df['Cloudiness']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
so_city_weather_df.plot(kind="scatter", x="Lat", y="Cloudiness",s = 98, grid=False, 
              figsize=(13,8), title = "Southern Hemi - Cloudiness vs Latitude")
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(-55,10),fontsize=18,color="red")
plt.xlabel('Latitude')
plt.ylabel('Cloudiness')
print(f"The r-squared is: {rvalue**2}")
plt.show()
# Out:
# The r-squared is: 0.00930619504171029

# %%
# Add the linear regression equation and line to plot for Northern hemi
x_values = no_city_weather_df['Lat']
y_values = no_city_weather_df['Cloudiness']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
no_city_weather_df.plot(kind="scatter", x="Lat", y="Cloudiness",s = 98, grid=False, 
              figsize=(13,8), title = "Northern Hemi - Cloudiness vs Latitude")
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(60,11),fontsize=18,color="red")
plt.xlabel('Latitude')
plt.ylabel('Cloudiness')
print(f"The r-squared is: {rvalue**2}")
plt.show()
# Out:
# The r-squared is: 0.001513310409347242

# %%
# Add the linear regression equation and line to plot for Southern hemi
x_values = so_city_weather_df['Lat']
y_values = so_city_weather_df['Wind Speed']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
so_city_weather_df.plot(kind="scatter", x="Lat", y="Wind Speed",s = 98, grid=False, 
              figsize=(13,8), title = "Southern Hemi - Wind Speed vs Latitude")
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(-55,25),fontsize=18,color="red")
plt.xlabel('Latitude')
plt.ylabel('Wind Speed')
print(f"The r-squared is: {rvalue**2}")
plt.show()
# Out:
# The r-squared is: 2.8769388736361296e-06

# %%
# Add the linear regression equation and line to plot for Northern hemi
x_values = no_city_weather_df['Lat']
y_values = no_city_weather_df['Wind Speed']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
no_city_weather_df.plot(kind="scatter", x="Lat", y="Wind Speed",s = 98, grid=False, 
              figsize=(13,8), title = "Northern Hemi - Wind Speed vs Latitude")
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(60,11),fontsize=18,color="red")
plt.xlabel('Latitude')
plt.ylabel('Wind Speed')
print(f"The r-squared is: {rvalue**2}")
plt.show()
# Out:
# The r-squared is: 0.027198544752586408
